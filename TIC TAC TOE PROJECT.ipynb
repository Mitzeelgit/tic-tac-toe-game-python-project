# %%
from IPython.display import clear_output

#MAKING DISPLAY BOARD

def display_board(board):
    clear_output()
    print(board[7] + '|' + board[8] + '|' + board[9] + '')
    print('-|-|-')
    print(board[4] + '|' + board[5] + '|' + board[6] + '')
    print('-|-|-')
    print(board[1] + '|' + board[2] + '|' + board[3] + '')

# %%
#TEST DISPLAY BOARD

test_board = ['#',' ','O','X','O','X','O','X','O','X']
display_board(test_board)
# Out:
# X|O|X
# -|-|-
# O|X|O
# -|-|-
#  |O|X

# %%
#FUNCTION TO ASSIGN A MARKER TO A PLAYER (EITHER X OR O)

def player_input():

    marker = 'wrong'

    marker_options = ['X' , 'O']

    while marker not in marker_options:
        marker = input('Choose a marker between X AND O :  ').upper()

        if marker not in marker_options:
            print('Sorry! invalid marker')

    player1 = marker

    if player1 == 'X':
        player2 = 'O'
    else:
        player1=='O'
        player2='X'

    return (player1,player2)

# %%
#FUNCTION TO PLACE THE MARKER ON THE BOARD ON A CERTAIN POSITION (1-9)
def place_marker(board,marker,position):

    board[position] = marker

# %%
place_marker(test_board,'$',7)
display_board(test_board)
# Out:
# $|O|X
# -|-|-
# O|X|O
# -|-|-
#  |O|X

# %%
#TO CHECK IF PLAYER HAS WON
def win_check(board,mark):

    return((board[1] == mark and board[2] == mark and board[3] == mark)or #1ST ROW
    (board[4] == mark and board[5] == mark and board[6] == mark) or #2ND ROW
    (board[7] == mark and board[8] == mark and board[9] == mark) or #3RD ROW
    (board[1] == mark and board[5] == mark and board[9] == mark) or #DIAGONAL (1)
    (board[7] == mark and board[5] == mark and board[3] == mark) or #DIAGONAL (2)
    (board[8] == mark and board[5] == mark and board[2] == mark) or #MIDDLE COLUMN
    (board[1] == mark and board[4] == mark and board[7] == mark) or #LEFT COLOUMN
    (board[9] == mark and board[6] == mark and board[3] == mark)) #RIGHT COLOUMN

# %%
win_check(test_board,'X')
# Out:
# True

# %%
#FUNCTION TO CHOOSE WHO STARTS PLAYER 1 OR 2

import random

def choose_first():
    if random.randint(0,1) == 0:
        return ('Player1')
    else:
        return ('Player2')

# %%
choose_first()
# Out:
# 'Player2'

# %%
#FUNCTION TO CHECK IF SPACE ON BOARD IS FREE

def space_check(board,position):

    if board[position] == ' ':
        return True
    else:
        return False

# %%
space_check(test_board , 2 )
# Out:
# False

# %%
def full_board_check(board):

    for i in range(0,10):
        if space_check(board,i):
            return False
    return True

# %%
full_board_check(test_board)
# Out:
# False

# %%
def player_choice(board):

    position = 0
    
    while position not in [1,2,3,4,5,6,7,8,9] or not space_check(board,position):
        position = int(input('Choose where to place a new marker between (1-9)'))
    return position

# %%
player_choice(test_board)
# Out:
# Choose where to place a new marker between (1-9) 2
# Choose where to place a new marker between (1-9) 1
# 1

# %%
def replay():
    
    return input('Do you want to play again? Enter Yes or No: ').lower().startswith('y')

# %% [raw]
# replay()

# %%
print('Welcome to Tic Tac Toe!')

while True:
    # Reset the board
    theBoard = [' '] * 10
    player1_marker, player2_marker = player_input()
    turn = choose_first()
    print(turn + ' will go first.')
    
    play_game = input('Are you ready to play? Enter Yes or No.')
    
    if play_game.lower()[0] == 'y':
        game_on = True
    else:
        game_on = False

    while game_on:
        if turn == 'Player 1':
            # Player1's turn.
            
            display_board(theBoard)
            position = player_choice(theBoard)
            place_marker(theBoard, player1_marker, position)

            if win_check(theBoard, player1_marker):
                display_board(theBoard)
                print('Congratulations! You have won the game!')
                game_on = False
            else:
                if full_board_check(theBoard):
                    display_board(theBoard)
                    print('The game is a draw!')
                    break
                else:
                    turn = 'Player 2'

        else:
            # Player2's turn.
            
            display_board(theBoard)
            position = player_choice(theBoard)
            place_marker(theBoard, player2_marker, position)

            if win_check(theBoard, player2_marker):
                display_board(theBoard)
                print('Player 2 has won!')
                game_on = False
            else:
                if full_board_check(theBoard):
                    display_board(theBoard)
                    print('The game is a draw!')
                    break
                else:
                    turn = 'Player 1'

    if not replay():
        break
# Out:
#  | |O
# -|-|-
#  |O|
# -|-|-
# O|X|X
# Player 2 has won!
# Do you want to play again? Enter Yes or No:  n
